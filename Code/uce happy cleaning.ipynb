# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %%
happy = pd.read_csv('/Users/uce/Desktop/DataAnalytics/data-labs/LabsUros/week5/Happiness-Team/Data/world-happiness-report_clean.csv')

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2156 entries, 0 to 2155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    2156 non-null   int64
#  1   country_name                  2156 non-null   object
#  2   year                          2156 non-null   int64
#  3   ladder_score                  2156 non-null   float64
#  4   logged_gdp_per_capita         2127 non-null   float64
#  5   social_support                2143 non-null   float64
#  6   healthy_life_expectancy       2104 non-null   float64
#  7   freedom_to_make_life_choices  2125 non-null   float64
#  8   generosity                    2074 non-null   float64
#  9   perceptions_of_corruption     2052 non-null   float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 168.6+ KB

# %%
happy.describe()
# Out:
#         Unnamed: 0         year  ladder_score  logged_gdp_per_capita  \
# count  2156.000000  2156.000000   2156.000000            2127.000000
# mean   1077.500000  2013.936456      5.455265               9.351845
# std     622.527911     4.539095      1.115322               1.162684
# min       0.000000  2005.000000      2.375000               6.492642
# 25%     538.750000  2010.000000      4.639750               8.449500
# 50%    1077.500000  2014.000000      5.385000               9.456000
# 75%    1616.250000  2018.000000      6.268250              10.341509
# max    2155.000000  2021.000000      8.019000              11.648000
#
#        social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# count     2143.000000              2104.000000                   2125.000000
# mean         0.811262                63.390488                      0.745607
# std          0.118823                 7.468284                      0.140415
# ...

# %%
happy.head(20)
# Out:
#     Unnamed: 0 country_name  year  ladder_score  logged_gdp_per_capita  \
# 0            0  Afghanistan  2008         3.724                  7.370
# 1            1  Afghanistan  2009         4.402                  7.540
# 2            2  Afghanistan  2010         4.758                  7.647
# 3            3  Afghanistan  2011         3.832                  7.620
# 4            4  Afghanistan  2012         3.783                  7.705
# 5            5  Afghanistan  2013         3.572                  7.725
# 6            6  Afghanistan  2014         3.131                  7.718
# 7            7  Afghanistan  2015         3.983                  7.702
# 8            8  Afghanistan  2016         4.220                  7.697
# 9            9  Afghanistan  2017         2.662                  7.697
# 10          10  Afghanistan  2018         2.694                  7.692
# 11          11  Afghanistan  2019         2.375                  7.697
# ...

# %%
sns.boxplot(x=happy['social_support'])
# Out:
# <AxesSubplot:xlabel='social_support'>

# %%
sns.boxplot(x=happy['logged_gdp_per_capita'])
# Out:
# <AxesSubplot:xlabel='logged_gdp_per_capita'>

# %%
sns.boxplot(x=happy['freedom_to_make_life_choices'])
# Out:
# <AxesSubplot:xlabel='freedom_to_make_life_choices'>

# %%
sns.boxplot(x=happy['perceptions_of_corruption'])
# Out:
# <AxesSubplot:xlabel='perceptions_of_corruption'>

# %%
happy.hist(figsize=(10, 8))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'ladder_score'}>],
#        [<AxesSubplot:title={'center':'logged_gdp_per_capita'}>,
#         <AxesSubplot:title={'center':'social_support'}>,
#         <AxesSubplot:title={'center':'healthy_life_expectancy'}>],
#        [<AxesSubplot:title={'center':'freedom_to_make_life_choices'}>,
#         <AxesSubplot:title={'center':'generosity'}>,
#         <AxesSubplot:title={'center':'perceptions_of_corruption'}>]],
#       dtype=object)

# %%
perc_null = np.where(happy['perceptions_of_corruption'].isnull() == True)

# %%
for key in happy.keys():
    print(key)
# Out:
# Unnamed: 0
# country_name
# year
# ladder_score
# logged_gdp_per_capita
# social_support
# healthy_life_expectancy
# freedom_to_make_life_choices
# generosity
# perceptions_of_corruption
